# %% [markdown]
# # HDSC Stage B Tag Along: Sachin Kumar Singh

# %% [markdown]
# # Loading Dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import sklearn
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'C:\Users\Sachin\Desktop\HAMOYE Codes\Stage 2\test_data.csv')
df
# Out:
#                       date  Appliances  lights         T1       RH_1  \
# 0      2016-01-11 17:00:00          60      30  19.890000  47.596667
# 1      2016-01-11 17:10:00          60      30  19.890000  46.693333
# 2      2016-01-11 17:20:00          50      30  19.890000  46.300000
# 3      2016-01-11 17:30:00          50      40  19.890000  46.066667
# 4      2016-01-11 17:40:00          60      40  19.890000  46.333333
# ...                    ...         ...     ...        ...        ...
# 19730  2016-05-27 17:20:00         100       0  25.566667  46.560000
# 19731  2016-05-27 17:30:00          90       0  25.500000  46.500000
# 19732  2016-05-27 17:40:00         270      10  25.500000  46.596667
# 19733  2016-05-27 17:50:00         420      10  25.500000  46.990000
# 19734  2016-05-27 18:00:00         430      10  25.500000  46.600000
#
#               T2       RH_2         T3       RH_3         T4  ...         T9  \
# ...

# %%
#renaming columns
new_columns={'T1': 'Kitchen_t','RH_1':'Kitchen_h','T2' :'Living_room_t',
             'RH_2':'Living_room_h','T3': 'laundry_room_t','RH_3':'laundry_room_h',
             'T4': 'office_room_t','RH_4':'office_room_h','T5': 'bathroom_t',
             'RH_5':'bathroom_h','T6': 'outside_the_building_northside_t',
             'RH_6':'outside_the_building_northside_h',
             'T7': 'ironing_room_t','RH_7':'ironing_room_h','T8': 'teenager_room_2 _t',
             'RH_8':'teenager_room_2 _h','T9': 'parents_room_t',
             'RH_9':'parents_room_h','T_out':'outside_t','RH_out':'outside_h'}
df=df.rename(columns=new_columns)
df
# Out:
#                       date  Appliances  lights  Kitchen_t  Kitchen_h  \
# 0      2016-01-11 17:00:00          60      30  19.890000  47.596667
# 1      2016-01-11 17:10:00          60      30  19.890000  46.693333
# 2      2016-01-11 17:20:00          50      30  19.890000  46.300000
# 3      2016-01-11 17:30:00          50      40  19.890000  46.066667
# 4      2016-01-11 17:40:00          60      40  19.890000  46.333333
# ...                    ...         ...     ...        ...        ...
# 19730  2016-05-27 17:20:00         100       0  25.566667  46.560000
# 19731  2016-05-27 17:30:00          90       0  25.500000  46.500000
# 19732  2016-05-27 17:40:00         270      10  25.500000  46.596667
# 19733  2016-05-27 17:50:00         420      10  25.500000  46.990000
# 19734  2016-05-27 18:00:00         430      10  25.500000  46.600000
#
#        Living_room_t  Living_room_h  laundry_room_t  laundry_room_h  \
# 0          19.200000      44.790000       19.790000       44.730000
# ...

# %%
df.head()
# Out:
#                   date  Appliances  lights  Kitchen_t  Kitchen_h  \
# 0  2016-01-11 17:00:00          60      30      19.89  47.596667
# 1  2016-01-11 17:10:00          60      30      19.89  46.693333
# 2  2016-01-11 17:20:00          50      30      19.89  46.300000
# 3  2016-01-11 17:30:00          50      40      19.89  46.066667
# 4  2016-01-11 17:40:00          60      40      19.89  46.333333
#
#    Living_room_t  Living_room_h  laundry_room_t  laundry_room_h  \
# 0           19.2      44.790000           19.79       44.730000
# 1           19.2      44.722500           19.79       44.790000
# 2           19.2      44.626667           19.79       44.933333
# 3           19.2      44.590000           19.79       45.000000
# 4           19.2      44.530000           19.79       45.000000
#
#    office_room_t  ...  parents_room_t  parents_room_h  outside_t  Press_mm_hg  \
# 0      19.000000  ...       17.033333           45.53   6.600000        733.5
# ...

# %%
df.isnull().sum()
# Out:
# date                                0
# Appliances                          0
# lights                              0
# Kitchen_t                           0
# Kitchen_h                           0
# Living_room_t                       0
# Living_room_h                       0
# laundry_room_t                      0
# laundry_room_h                      0
# office_room_t                       0
# office_room_h                       0
# bathroom_t                          0
# bathroom_h                          0
# outside_the_building_northside_t    0
# outside_the_building_northside_h    0
# ironing_room_t                      0
# ironing_room_h                      0
# teenager_room_2 _t                  0
# teenager_room_2 _h                  0
# parents_room_t                      0
# parents_room_h                      0
# outside_t                           0
# Press_mm_hg                         0
# outside_h                           0
# Windspeed                           0
# ...

# %% [markdown]
# # Ans 12 :-   1.0

# %%
x=df['Living_room_t'].values
x=x.reshape(len(x),1)
y=df['Living_room_t'].values

# %%
from sklearn.linear_model import LinearRegression
linear_model = LinearRegression()

# %%
#fit the model to the training dataset
fit1=linear_model.fit(x, y)

# %%
#obtain predictions
predicted_values = linear_model.predict(x)

# %% [markdown]
# Obtaining the  R^2 value

# %%
from sklearn.metrics import r2_score
r2_score = r2_score(y, predicted_values)
round(r2_score, 3)
# Out:
# 1.0

# %% [markdown]
# # Ans 13 :-  53.643

# %%
#normalize dataset to common scale using min max scaler
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
normalised_df=df.drop(columns=['date','lights','Appliances'])
features_df=pd.DataFrame(scaler.fit_transform(normalised_df),columns=normalised_df.columns)   
y=df['Appliances'].values
x=normalised_df.values

# %%
#now we split data into training and testing dataset.
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
linear_model = LinearRegression()

# %%
#fit the model to the training dataset
linear_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#obtain predictions
predicted_values = linear_model.predict(x_test)

# %%
#MAE
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, predicted_values)
round(mae, 3)
# Out:
# 53.643

# %% [markdown]
# # Ans 14:- 51918501.21

# %%
#RSS value 
import numpy as np
rss = np.sum(np.square(y_test - predicted_values))
round(rss, 3)
# Out:
# 51918501.212

# %% [markdown]
# # Ans 15 :- 93.640

# %%
# ● Root Mean Square Error (RMSE)
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, predicted_values))
round(rmse, 3)
# Out:
# 93.64

# %% [markdown]
# # Ans 16:-  0.15

# %%
# ● R-Squared or coefficient of determination
from sklearn.metrics import r2_score
r2_score = r2_score(y_test,predicted_values )
round(r2_score, 2)
# Out:
# 0.15

# %% [markdown]
# # Ans 18

# %%
from sklearn.linear_model import Ridge
ridge_reg = Ridge(alpha=0.4)
ridge_reg.fit(x_train, y_train)

# %%
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(x_test, y_test))
round(rmse, 3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10648/4203428935.py in <module>
#       1 from sklearn.metrics import mean_squared_error
# ----> 2 rmse = np.sqrt(mean_squared_error(x_test, y_test))
#       3 round(rmse, 3)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     333     0.825...
#     334     """
# --> 335     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     336         y_true, y_pred, multioutput)
# ...

# %%
# from sklearn.linear_model import Lasso
# lasso_reg = Lasso(alpha=0.001)
# lasso_reg.fit(x_train, y_train)

# %%
#comparing the effects of regularisation
def get_weights_df(model, feat, col_name):
    #this function returns the weight of every feature
    weights = pd.Series(model.coef_, feat.columns).sort_values()
    weights_df = pd.DataFrame(weights).reset_index()
    weights_df.columns = ['Features', col_name]
    weights_df[col_name].round(3)
    return weights_df
linear_model_weights = get_weights_df(linear_model, x_train, 'Linear_Model_Weight')
ridge_weights_df = get_weights_df(ridge_reg, x_train, 'Ridge_Weight')
lasso_weights_df = get_weights_df(lasso_reg, x_train, 'Lasso_weight')
final_weights = pd.merge(linear_model_weights, ridge_weights_df, on='Features')
final_weights = pd.merge(final_weights, lasso_weights_df, on='Features')
final_weights.sort_values("Linear_Model_Weight", ascending=False)
